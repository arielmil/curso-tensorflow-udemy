# %%
import tensorflow as tf
# Out:
# 2024-02-08 05:55:08.469667: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:08.469724: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
a = tf.add(2, 2, name = 'add')
b = tf.multiply(a, 3, name = 'mult1')
c = tf.multiply(b, a, name = 'mult2')
# Out:
# 2024-02-08 05:55:10.051880: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2024-02-08 05:55:10.323831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-08 05:55:10.324065: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1060 computeCapability: 6.1
# coreClock: 1.6705GHz coreCount: 10 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 178.99GiB/s
# 2024-02-08 05:55:10.324147: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:10.324226: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:10.324294: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:10.324358: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:10.324421: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:10.324486: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:10.324548: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:10.324613: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2024-02-08 05:55:10.324622: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-02-08 05:55:10.325517: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-08 05:55:10.325927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-02-08 05:55:10.325953: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]

# %% [markdown]
# Em modo *eager*, os grafos são construídos e destruídos em tempo real.

# %%
c.graph
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 c.graph
#
# File ~/anaconda3/envs/IA/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:401, in Tensor.__getattr__(self, name)
#     393 if name in {"T", "astype", "ravel", "transpose", "reshape", "clip", "size",
#     394             "tolist", "data"}:
#     395   # TODO(wangpeng): Export the enable_numpy_behavior knob
#     396   raise AttributeError("""
#     397     '{}' object has no attribute '{}'.
#     398     If you are looking for numpy-related methods, please run the following:
#     399     import tensorflow.python.ops.numpy_ops.np_config
#     400     np_config.enable_numpy_behavior()""".format(type(self).__name__, name))
# --> 401 self.__getattribute__(name)
#
# File ~/anaconda3/envs/IA/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1250, in _EagerTensorBase.graph(self)
#    1248 @property
#    1249 def graph(self):
# -> 1250   raise AttributeError(
#    1251       "Tensor.graph is meaningless when eager execution is enabled.")
#
# AttributeError: Tensor.graph is meaningless when eager execution is enabled.

# %% [markdown]
# Existe um grafo padrão, mas ele não é utilizado.

# %%
tf.compat.v1.get_default_graph()

# %% [markdown]
# Verificando o grafo construído em tempo real.

# %%
writer = tf.summary.create_file_writer('/content/output')
a = tf.add(2, 2, name = 'add')
b = tf.multiply(a, 3, name = 'mult1')
c = tf.multiply(b, a, name = 'mult2')
writer.close()

# %%
with tf.name_scope('Operacoes'):
    writer = tf.summary.create_file_writer('/content/output')
    with tf.name_scope('Escopo_A'):
        a = tf.add(2, 2, name = 'add')
    with tf.name_scope('Escopo_B'):
        b = tf.multiply(a, 3, name = 'mult1')
        c = tf.multiply(b, a, name = 'mult2')
    writer.close()
# Out:
# 2024-02-08 05:55:58.290844: W tensorflow/core/framework/op_kernel.cc:1767] OP_REQUIRES failed at summary_kernels.cc:57 : Permission denied: /content; Permission denied
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[4], line 2
#       1 with tf.name_scope('Operacoes'):
# ----> 2     writer = tf.summary.create_file_writer('/content/output')
#       3     with tf.name_scope('Escopo_A'):
#       4         a = tf.add(2, 2, name = 'add')
#
# File ~/anaconda3/envs/IA/lib/python3.9/site-packages/tensorflow/python/ops/summary_ops_v2.py:506, in create_file_writer_v2(logdir, max_queue, flush_millis, filename_suffix, name)
#     504 else:
#     505   shared_name = ops.name_from_scope_name(scope)  # pylint: disable=protected-access
# --> 506 return ResourceSummaryWriter(
#     507     shared_name=shared_name,
#     508     init_op_fn=functools.partial(
#     509         gen_summary_ops.create_summary_file_writer,
#     510         logdir=logdir,
#     511         max_queue=max_queue,
#     512         flush_millis=flush_millis,
#     513         filename_suffix=filename_suffix),
#     514     name=name,
#     515     v2=True,
#     516     metadata={"logdir": logdir})
#
# File ~/anaconda3/envs/IA/lib/python3.9/site-packages/tensorflow/python/ops/summary_ops_v2.py:285, in ResourceSummaryWriter.__init__(self, shared_name, init_op_fn, name, v2, metadata)
#     283 # TODO(nickfelt): cache other constructed ops in graph mode
#     284 self._init_op_fn = init_op_fn
# --> 285 self._init_op = init_op_fn(self._resource)
#     286 self._v2 = v2
#     287 self._metadata = {} if metadata is None else metadata
#
# File ~/anaconda3/envs/IA/lib/python3.9/site-packages/tensorflow/python/ops/gen_summary_ops.py:146, in create_summary_file_writer(writer, logdir, max_queue, flush_millis, filename_suffix, name)
#     144   return _result
#     145 except _core._NotOkStatusException as e:
# --> 146   _ops.raise_from_not_ok_status(e, name)
#     147 except _core._FallbackException:
#     148   pass
#
# File ~/anaconda3/envs/IA/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:6897, in raise_from_not_ok_status(e, name)
#    6895 message = e.message + (" name: " + name if name is not None else "")
#    6896 # pylint: disable=protected-access
# -> 6897 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# PermissionDeniedError: /content; Permission denied [Op:CreateSummaryFileWriter]

# %% [markdown]
# É possível forçar a execução dentro de um grafo explícito (em modo *lazy*):

# %%
grafo = tf.Graph()

# %%
grafo

# %%
with grafo.as_default():
    a = tf.add(2, 2, name = 'add')
    b = tf.multiply(a, 3, name = 'mult1')
    c = tf.multiply(b, a, name = 'mult2')
    print(c.graph is grafo)
# Out:
# True
