# %%
import pandas as pd
base = pd.read_csv('census.csv')
base.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
# 3   53            Private        234721  ...            40   United-States   <=50K
# 4   28            Private        338409  ...            40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
base['income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
def converte_classe(rotulo):
    if rotulo == ' >50K':
        return 1
    else:
        return 0

# %%
base['income'] = base['income'].apply(converte_classe)

# %%
base.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country income
# 0   39          State-gov         77516  ...            40   United-States      0
# 1   50   Self-emp-not-inc         83311  ...            13   United-States      0
# 2   38            Private        215646  ...            40   United-States      0
# 3   53            Private        234721  ...            40   United-States      0
# 4   28            Private        338409  ...            40            Cuba      0
#
# [5 rows x 15 columns]

# %%
base['income'].unique()
# Out:
# array([0, 1])

# %%
X = base.drop('income', axis = 1)

# %%
X.head()
# Out:
#    age          workclass  ...  hour-per-week  native-country
# 0   39          State-gov  ...             40   United-States
# 1   50   Self-emp-not-inc  ...             13   United-States
# 2   38            Private  ...             40   United-States
# 3   53            Private  ...             40   United-States
# 4   28            Private  ...             40            Cuba
#
# [5 rows x 14 columns]

# %%
y = base['income']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
base.age.hist()

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %%
idade = tf.feature_column.numeric_column('age')

# %%
idade_categorica = [tf.feature_column.bucketized_column(idade, boundaries = [20, 30, 40, 50, 60, 70, 80, 90])]

# %%
print(idade_categorica)
# Out:
# [BucketizedColumn(source_column=NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(20, 30, 40, 50, 60, 70, 80, 90))]

# %%
X.columns
# Out:
# Index(['age', 'workclass', 'final-weight', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loos', 'hour-per-week', 'native-country'],
#       dtype='object')

# %%
nome_colunas_categoricas = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']

# %%
X['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
X['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
X['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
colunas_categoricas = [tf.feature_column.categorical_column_with_vocabulary_list(key = c, vocabulary_list = X[c].unique()) for c in nome_colunas_categoricas]

# %%
print(colunas_categoricas[3])
# Out:
# VocabularyListCategoricalColumn(key='occupation', vocabulary_list=(' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair', ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct', ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces', ' Priv-house-serv'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
nome_colunas_numericas = ['final-weight', 'education-num', 'capital-gain', 'capital-loos', 'hour-per-week']

# %%
colunas_numericas = [ tf.feature_column.numeric_column(key = c) for c in nome_colunas_numericas ]

# %%
print(colunas_numericas[1])
# Out:
# NumericColumn(key='education-num', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)

# %%
colunas = idade_categorica + colunas_categoricas + colunas_numericas

# %%
from sklearn.model_selection import train_test_split
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_treinamento.shape
# Out:
# (22792, 14)

# %%
X_teste.shape
# Out:
# (9769, 14)

# %%
def make_input_fn(X, y = None, num_epochs = None, shuffle = True, batch_size = 32):
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(X), y))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds
    return input_function

# %%
funcao_treinamento = make_input_fn(X_treinamento, y_treinamento)

# %%
config = tf.estimator.RunConfig(tf_random_seed = 24)
classificador = tf.estimator.LinearClassifier(feature_columns = colunas, config = config)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp0mg6t_mx
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp0mg6t_mx', '_tf_random_seed': 24, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
classificador.train(input_fn = funcao_treinamento, steps = 10000)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/canned/linear.py:1481: Layer.add_variable (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/ftrl.py:112: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp0mg6t_mx/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 283.717
# INFO:tensorflow:loss = 419.5031, step = 100 (0.353 sec)
# INFO:tensorflow:global_step/sec: 647.31
# INFO:tensorflow:loss = 950.536, step = 200 (0.155 sec)
# INFO:tensorflow:global_step/sec: 629.331
# INFO:tensorflow:loss = 741.182, step = 300 (0.159 sec)
# INFO:tensorflow:global_step/sec: 610.133
# INFO:tensorflow:loss = 517.781, step = 400 (0.164 sec)
# INFO:tensorflow:global_step/sec: 619.106
# INFO:tensorflow:loss = 86.13359, step = 500 (0.162 sec)
# INFO:tensorflow:global_step/sec: 627.704
# INFO:tensorflow:loss = 105.007454, step = 600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 604.101
# INFO:tensorflow:loss = 32.877647, step = 700 (0.166 sec)
# INFO:tensorflow:global_step/sec: 618.521
# INFO:tensorflow:loss = 126.19837, step = 800 (0.164 sec)
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 843 vs previous value: 843. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:global_step/sec:
# INFO:tensorflow:loss = 35.597313, step = 9000 (0.161 sec)
# INFO:tensorflow:global_step/sec: 616.223
# INFO:tensorflow:loss = 40.659363, step = 9100 (0.162 sec)
# INFO:tensorflow:global_step/sec: 622.34
# INFO:tensorflow:loss = 9.880495, step = 9200 (0.161 sec)
# INFO:tensorflow:global_step/sec: 596.416
# INFO:tensorflow:loss = 115.172676, step = 9300 (0.168 sec)
# INFO:tensorflow:global_step/sec: 640.009
# INFO:tensorflow:loss = 87.83011, step = 9400 (0.156 sec)
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 9434 vs previous value: 9434. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:global_step/sec: 645.451
# INFO:tensorflow:loss = 24.887026, step = 9500 (0.155 sec)
# INFO:tensorflow:global_step/sec: 638.88
# INFO:tensorflow:loss = 15.672285, step = 9600 (0.157 sec)
# INFO:tensorflow:global_step/sec: 633.239
# INFO:tensorflow:loss = 10.08043, step = 9700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 619.93
# INFO:tensorflow:loss = 244.39275, step = 9800 (0.162 sec)
# INFO:tensorflow:global_step/sec: 634.038
# INFO:tensorflow:loss = 7.35376, step = 9900 (0.158 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmp0mg6t_mx/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:Loss for final step: 142.78262.

# %%
funcao_previsao = make_input_fn(X_teste, num_epochs = 1, shuffle = False)

# %%
previsoes = classificador.predict(input_fn = funcao_previsao)

# %%
list(previsoes)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp0mg6t_mx/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-616.1174], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-136.61736], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-613.69214], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-698.0315], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-585.0956], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-310.9071], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([1.], dtype=float32),
#   'logits': array([505.43182], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-583.79803], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1135.842], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([4.730479e-25], dtype=float32),
#   'logits': array([-56.0106], dtype=float32),
#   'probabilities': array([1.000000e+00, 4.730479e-25], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-854.3805], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-997.1949], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-524.70215], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-385.4489], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-805.89996], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-617.3577], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-128.16597], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-557.923], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9999978], dtype=float32),
#   'logits': array([13.036766], dtype=float32),
#   'probabilities': array([2.1787305e-06, 9.9999785e-01], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-961.11475], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1560.7129], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-346.67932], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-319.40613], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-870.51184], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-137.53065], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-554.1551], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-619.02374], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-853.7137], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-453.77832], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-877.3125], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-406.39215], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-634.88617], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-967.3807], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-394.91895], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1174.2992], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-386.13934], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-705.264], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1641.8286], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-698.63025], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-355.40723], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-590.64856], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1042.5563], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([1.], dtype=float32),
#   'logits': array([4878.8516], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-180.87242], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-779.8261], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-480.08307], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-900.1808], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1316.8456], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-619.3299], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-520.5277], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-509.45404], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-747.70636], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([2.5057986e-27], dtype=float32),
#   'logits': array([-61.25119], dtype=float32),
#   'probabilities': array([1.0000000e+00, 2.5057986e-27], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1310.55], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-626.505], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-459.91577], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-701.7075], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-349.8352], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([7.8059137e-16], dtype=float32),
#   'logits': array([-34.78648], dtype=float32),
#   'probabilities': array([1.0000000e+00, 7.8059137e-16], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1034.1824], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-839.3871], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-419.2589], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-512.8634], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-897.0082], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-597.53217], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-427.2398], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-601.69476], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1054.9993], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-647.1136], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-117.45206], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-957.8727], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-434.43054], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-657.78217], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1229.45], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-92.624084], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([1.3225014e-32], dtype=float32),
#   'logits': array([-73.4032], dtype=float32),
#   'probabilities': array([1.0000000e+00, 1.3225014e-32], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-843.6322], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-509.26666], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-350.5504], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1118.4736], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([1.], dtype=float32),
#   'logits': array([189.5612], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1212.0444], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([1.], dtype=float32),
#   'logits': array([354.4018], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-158.42467], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-660.16174], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-680.18945], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-637.154], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-138.28618], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-850.4086], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1440.3823], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-339.76416], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-175.21495], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-828.58923], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1147.8793], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-272.73712], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-901.7691], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-406.0736], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-366.90643], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-843.4154], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-156.5148], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-173.21492], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-360.93195], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1355.9744], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-747.6387], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-485.13837], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1163.0372], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-362.8546], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-568.34467], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1293.9745], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-586.61194], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-255.40942], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-333.3991], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-496.82526], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-590.1239], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-665.762], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-695.9992], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([1.], dtype=float32),
#   'logits': array([139.94624], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-126.847725], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-109.33179], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-434.45898], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-452.7602], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-551.7743], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-545.7102], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-552.6071], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-179.15715], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-294.94537], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-750.7422], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-706.49426], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-662.5935], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-525.6289], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-247.59677], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-639.59827], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-263.8681], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-246.42851], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-578.52155], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([4.4711674e-24], dtype=float32),
#   'logits': array([-53.764393], dtype=float32),
#   'probabilities': array([1.0000000e+00, 4.4711674e-24], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-564.4908], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-166.83133], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-340.99512], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-285.1407], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-852.8392], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-760.8668], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-336.54785], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1083.5747], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-933.8278], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-587.1428], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-787.2514], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-423.49487], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1144.307], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1195.0397], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-531.5027], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-495.79694], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-495.69928], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
# ...
#   'logits': array([-1598.5497], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-313.9829], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-465.3777], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-625.8751], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-471.09613], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1123.7072], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-459.8011], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1006.48584], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-629.0257], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-466.51288], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-429.39844], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-780.8757], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-474.88495], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-698.6788], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([1.], dtype=float32),
#   'logits': array([4573.168], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.99916637], dtype=float32),
#   'logits': array([7.088871], dtype=float32),
#   'probabilities': array([8.3364331e-04, 9.9916637e-01], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-568.7159], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-257.1795], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-556.72046], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1388.6438], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-616.9893], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([1.], dtype=float32),
#   'logits': array([50.164516], dtype=float32),
#   'probabilities': array([1.636166e-22, 1.000000e+00], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-541.81384], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-822.33014], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([5.4927992e-30], dtype=float32),
#   'logits': array([-67.374115], dtype=float32),
#   'probabilities': array([1.0000000e+00, 5.4927992e-30], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-754.06946], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-406.9967], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-649.944], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1072.3362], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-866.976], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-820.58295], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-582.917], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-510.18127], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-268.55695], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-637.2218], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-332.8042], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-273.06116], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-631.5142], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-171.96082], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-133.03265], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1039.5321], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-614.79266], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1417.8129], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-711.05786], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-722.7939], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-553.7324], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-661.06445], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-303.61285], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-1186.1655], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-647.4945], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([1.], dtype=float32),
#   'logits': array([1299.9777], dtype=float32),
#   'probabilities': array([0., 1.], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.], dtype=float32),
#   'logits': array([-728.28815], dtype=float32),
#   'probabilities': array([1., 0.], dtype=float32)},
#  ...]

# %%
previsoes_final = []
for p in classificador.predict(input_fn = funcao_previsao):
    previsoes_final.append(p['class_ids'])
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp0mg6t_mx/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
previsoes_final
# Out:
# [array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  ...]

# %%
from sklearn.metrics import accuracy_score
taxa_acerto = accuracy_score(y_teste, previsoes_final)
taxa_acerto
# Out:
# 0.7871839492271471
