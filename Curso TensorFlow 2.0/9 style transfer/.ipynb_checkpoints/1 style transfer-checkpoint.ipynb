# %% [markdown]
# ## Style Transfer
#
# Esta aula é baseada no tutorila disponibilizado no [site oficial do TensorFlow](https://www.tensorflow.org/tutorials/generative/style_transfer?hl=en).

# %% [markdown]
# ### 1. Carregando dependências

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf

from datetime import datetime

# %% [markdown]
# ## 2. Carregando e preparando o modelo
#
# Vamos usar o modelo VGG19 sem o topo, que é a parte final da rede que faz a classificação das imagens.

# %%
model = tf.keras.applications.VGG19(include_top=False, weights='imagenet')

# %%
for i, layer in enumerate(model.layers):
    print(i, layer.name)
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_conv4
# 11 block3_pool
# 12 block4_conv1
# 13 block4_conv2
# 14 block4_conv3
# 15 block4_conv4
# 16 block4_pool
# 17 block5_conv1
# 18 block5_conv2
# 19 block5_conv3
# 20 block5_conv4
# 21 block5_pool

# %% [markdown]
# ## 3. Processamento das imagens
#
# Vamos baixar uma image de conteúdo, sendo uma foto do Chaves, e uma imagem de estilo, sendo um auto-retrato do Van Gogh.

# %%
# !wget https://en.wikipedia.org/wiki/File:Vincent_van_Gogh_-_Self-Portrait_-_Google_Art_Project.jpg vangogh.jpg
# !wget https://img.huffingtonpost.com/asset/5d726f5f240000fb1777c53b.jpeg?ops=scalefit_630_noupscale chaves.jpeg
# Out:
# 'wget' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.
# 'wget' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
cont_img = Image.open('chaves.jpeg')
cont_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=598x448 at 0x1ED2B75BD90>

# %%
style_img = Image.open('vangogh.jpg')
style_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x547 at 0x1ED2BB28B50>

# %% [markdown]
# Para facilitar o processamento, vamos recarregar as imagens usando funções do TensorFlow.

# %%
cont_img = tf.io.read_file('chaves.jpeg')
cont_img
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'\xff\xd8\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc0\x00\x11\x08\x01\xc0\x02V\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x00\x07\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\xff\xc4\x00L\x10\x00\x01\x03\x03\x02\x04\x04\x04\x03\x03\t\x07\x03\x03\x03\x05\x02\x00\x01\x03\x04\x05\x12\x06\x11\x13!"1\x072AB\x14QRb#ar\x153q$C\x81\x82\x91\x92\xa1\xb1\xb2\x08\x16%S\xa2\xc1\xc2\x17c\xd14\xd2\xf0&s\x835D\xe1\xe2\xf2\xff\xc4\x00\x1b\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x00\x01\x04\x05\x06\x07\xff\xc4\x00.\x11\x00\x02\x02\x01\x03\x04\x02\x02\x01\x05\x00\x02\x03\x00\x00\x00\x00\x01\x02\x03\x11\x04\x12!\x05\x13"12A\x14QB\x15#3Raq\x81$b\xa1\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xd1a\xfc\x12\x83\xd5+\x14x\xf4\xfd\xcb\xd1\x9c\x80\x84qJ\xf5D"\x96"\xa1a\x8fwJ\x1e\xe8\x08\xb6\xe9x\xab\xc9\x02\xf2\xa5\x7fu\x02\x14\x18qC\x92\x05\xe5\xf9:\x1f\xea\xfe\tx\xa0 \xa1\x04\x12W\xa22\x14\xb6\x1e\x95Y \x8cy%\x7fu\x1e(\x08(@\xbd\xbe\x88\x93\x98#\xc7\x16P\x82=\xde\x89C\xdb\xd1\x06\x0fR\xe6\x92\xf8\x0f\x9b\xca*\x10Quy\xbf\xc9\'\'\xdb\xed\xfe\x0b1\xa8\xf5\x9d\x15\xb3\x8b\x10~%C7!\x15\x90\x93_V\xfe\xcd\x1a\x98\xb0\xc4\x9f\x17\xcf\xbb\n\t\\\xa0\x12\x83:\xc7/\x97\xf8$\xf9[\xb3.KM\xe25\xd3\x8d\xc3\xe1\xc6c\xb6L\x7fW\xe4\xb46\x9dSp\xaf\xa5\x8e\xb6*-\xe1#\xc1\xc8\x1f\x90\x92\x1e\xfc\x19;f\xe7.C\xdb\xfb\x12\x87\xff\x00\xceK!r\xd6\x90R\xf28$\n\x81|L6NZ\xf5\x9d\xaax\xf39\x1e3\xfaO\xda\xa7z\x1f\xb2lf\xb0{\xec\x8b\xd7eJ\xfa\xa6\xd00\xf1\n\xae\x17\xfbw\xeaU2\xeb\x8a(\xe19s\xe2R3\xf9\xb7E\xdc_\xb2lf\xc4\xba[\xb7\xf8,\x9e\xb8\xbd=\xa6\xd6n\x06\xccf\xa2]\xb5\xd5\xbe;i\xc9K#\x9em\xd1\xfa\x97 \xbe\xde\xab.\xaeY1\xccE\xdb\x9f\x95"\xfdJK\x088V.\xba\xedQT\x7f\x8dPf;\xe6\xd9(\x90T\xc96\\/(\xbeY\x93wP\xa5\xb7\xd6\x14bd\xcc\xe2\xcd\xe5\xf5W\xdab\x8b\n#\n\xb6\xe9\xdf\xf0\xf2\\\xb7-\xec\xd1\x84ZZ-53BYm\xd4\xf91\xef\xd9O\nC\xa7\x84\xe3\x9bg!|\xdb\x16R\xa9\x08#\x8e0\tv!\xf3\x82T\xf1\xe2\x06\xe2ld/\xccI\xf9\x8b&\xc7\x02\x8a\xa8ix\x95<Qg\xe2yq\xfc\x94k\x95+\x90\x8b\xe0\xed\x8f\x90}\x19\\U\x9cE\x0f\x16\'\xe0O\x1bb\xdfx\xaa\xcf\xda\x86#\x81\xb6c\xbf\x93\xd0\x91\xa4\x8b*`\x8e\xa4\xa6\x13\x00\x07\x06\xf3\xa9w\xb2\x90\xe3/\x87p,\x9b\x98\x9fvJ\x98\xa3\xa83\x90\xdc\xe9\xa0?`\xf6\xddH\x92\x9a\x9e\xa0\x19\xe1\x90\x1bf\xf3n\x8b\x0b\x01"\x9e\xcdZrE/\x17\x00\x10|X\xd4\xfa\xea\xa8\x8a\x18\xe7\t6\x06\xfd\xe6-\xfe\x94#\x82(a\'\xc0\x1a?Q\xf9\xbaj\x86\x1f\xe5\x83\xc5\x8c$\xa7\xf3!L\x84\xa8\xc8\x06\x84\xaa\xe8d\x07\'\xeaq$\xc8\xdc[1\x92zxd\x85\xc3.]\xc5\xd5u\xfa\x03\xa4\xba\xefN\xee\xf4\xfb{;*\xc8$0\xab\xe1\x03;C\xbe]\xd59\x97\x83R\x05G7\xf2\x8ay\x01\xc8\xbd\x92\xb2\x91O\x1f\xc4\xc2\xdcgf6\xf6\x9bd\xc6\xa8\xc0\xa2\x8cz\x9d\xc0\xfd\x04}U\x84c\'\x18\x02\x96^8\xf4\x93\t&"\x88s\x90H{Jm\xcb\xd9\xb2\xb5\xa7\xa6\x8e\xa1\xa8\xce\x94\xd8\xceO\xdfe\xe8\x9b\xbcP\xc5 \x1dd \xc0#\xd3 }\x04\xac\xact\xa6\x10\xc2b\xdb\xf3m\xf1oE"\xb9\x05\x9b\xaa(h\xe0\xa0\x86\x9c\xdf2.\x962eCt\xa6\x01\x94\xe3\xe81\x17\xc8\xf0n\xa1Wur\x1f\xc3\x04\x90\xc0\xd2\x00;\x0b\xb7\xab#\x9e\x85\xa4\xb9\x05]/\xeedl\x8c\x85\xbc\xbf\x91\'8\xa02V\x1d\x9f\xfe\x1c\x12\x03\x0bf\xdc\xb2e\xcd\xf5U$\xb4\xf5\x1b\x93\xed\xb7S~\x95\xd8nR4\xd4{D\x7f\x8c\xddX\x0f\xb9\x97\x16\xd77W\x92\xa4\xe0\x88\x1f\x16\xef\xf2\xfe\t\x16\xc1!\xb0y)\x82LOzs\xda@\xeae\xb9\xd3z\xbb\x8e!\x05\xc06\x93\xc9\x98\xfb\x9d`)N)\xe1\x1e\x0b\xb4so\x8f\xf4&d\x91\xe9\xea\x0c7\xe8\xcf\x992VphSgui\x8c\xb9\x8b!\xf8\x98\xac\xae\x80\xbf\xfcV4Un\xc4m\xd8\xc9o8 -\xdd\xb1X5\x1a\xf9\xd4\xf1\x83u5wQZ1\x99y\x92\xc2\x07\xcb\xa5\x94\xb3(\xa3\xf5e\x1eZ\xd0\x0f*\xc2\xef\xb6\xf7\xc0\xf5L!\xcc\x87\x1a\x16\x8f\x99l\xa2\xd4\xd4\xf5`;&&\xaby\x0b\xa5Dr|\xbdWWC\xd3\xb2\xf7Xd\xd5kT\x16\xd8\x93 ...

# %% [markdown]
# A imagem é carregada em formato de string. Vamos decodificá-la para inteiros com 3 canais de cores.

# %%
cont_img = tf.image.decode_image(cont_img, channels = 3)
cont_img
# Out:
# <tf.Tensor: shape=(448, 598, 3), dtype=uint8, numpy=
# array([[[121, 155, 203],
#         [121, 155, 203],
#         [121, 155, 203],
#         ...,
#         [ 97, 118, 139],
#         [ 97, 118, 139],
#         [ 97, 118, 139]],
#
#        [[123, 157, 205],
#         [123, 157, 205],
#         [123, 157, 205],
#         ...,
#         [ 99, 120, 141],
#         [ 99, 119, 143],
#         [ 99, 120, 141]],
#
#        [[123, 157, 205],
#         [123, 157, 205],
#         [123, 157, 205],
#         ...,
#         [ 98, 120, 143],
#         [ 98, 120, 144],
#         [ 98, 120, 143]],
#
#        ...,
#
#        [[184, 220, 254],
#         [184, 220, 254],
#         [184, 220, 254],
#         ...,
#         [255, 251, 252],
#         [255, 250, 251],
#         [255, 250, 250]],
#
#        [[185, 221, 255],
#         [184, 220, 254],
#         [184, 220, 254],
#         ...,
#         [255, 249, 250],
#         [255, 251, 252],
#         [255, 252, 252]],
#
#        [[185, 221, 255],
#         [185, 221, 255],
#         [184, 220, 254],
#         ...,
#         [255, 250, 251],
#         [255, 250, 251],
#         [255, 252, 252]]], dtype=uint8)>

# %% [markdown]
# E agora converter para tipo float. Verificando os 5 primeiros pixels nas direções horizontal e vertical, observamos que os valores agora foram também normalizados para o intervalo [0, 1].

# %%
cont_img = tf.image.convert_image_dtype(cont_img, tf.float32)
cont_img[:5, :5, 0]
# Out:
# <tf.Tensor: shape=(5, 5), dtype=float32, numpy=
# array([[0.47450984, 0.47450984, 0.47450984, 0.47450984, 0.47450984],
#        [0.48235297, 0.48235297, 0.48235297, 0.48235297, 0.48235297],
#        [0.48235297, 0.48235297, 0.48235297, 0.48235297, 0.48235297],
#        [0.48235297, 0.48235297, 0.48235297, 0.48235297, 0.48235297],
#        [0.48627454, 0.48627454, 0.48627454, 0.48627454, 0.48627454]],
#       dtype=float32)>

# %% [markdown]
# Agora vamos redimensionar a imagem para ter no máximo 512 pixels na maior dimensão. Primeiro definimos uma escala que vai resultar neste valor.

# %%
shape = tf.cast(tf.shape(cont_img)[:-1], tf.float32) # estamos descartando a terceira dimensão (das cores), e convertendo para float, para poder dividir em seguida
long_dim = max(shape)
scale = 512/long_dim
scale
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8561873>

# %% [markdown]
# Agora multiplicamos o formato original por esta escala.

# %%
new_shape = tf.cast(shape * scale, tf.int32)
cont_img = tf.image.resize(cont_img, new_shape)
cont_img.shape
# Out:
# TensorShape([383, 512, 3])

# %% [markdown]
# Veja que a maior dimensão agora é igual a 512.
#
# Precisamos ainda incluir uma dimensão no início da imagem, que corresponde à dimensão de batch.

# %%
cont_img = cont_img[tf.newaxis, :]
cont_img.shape
# Out:
# TensorShape([1, 383, 512, 3])

# %% [markdown]
# Agora repetimos para a imagem de estilo.

# %%
# Carregamento e conversão em float
style_img = tf.io.read_file('vangogh.jpg')
style_img = tf.image.decode_image(style_img, channels = 3)
style_img = tf.image.convert_image_dtype(style_img, tf.float32)

# Redimensionamento
shape = tf.cast(tf.shape(style_img)[:-1], tf.float32) # estamos descartando a terceira dimensão (das cores), e convertendo para float, para poder dividir em seguida
long_dim = max(shape)
scale = 512/long_dim
new_shape = tf.cast(shape * scale, tf.int32)
style_img = tf.image.resize(style_img, new_shape)

# Inserção da dimensão de batch
style_img = style_img[tf.newaxis, :]

# %% [markdown]
# Vai ser útil criar uma função para visualizar as imagens.

# %%
def show_img(img):
    img = tf.squeeze(img, axis = 0) # para retirar a dimensão de batch
    return img

# %% [markdown]
# Visualizando as imagens processadas.

# %%
fig, axes = plt.subplots(1, 2, figsize = (15, 10))
axes[0].imshow(show_img(cont_img))
axes[1].imshow(show_img(style_img))

# %% [markdown]
# ## 4. Preparação da estrutura da rede
#
# Com base no nome das camadas visualizado acima, vamos definir quais são as camadas responsáveis por conteúdo e por estilo.

# %%
content_layers = ['block5_conv2']
style_layers = ['block1_conv1', 'block2_conv1', 'block3_conv1', 'block4_conv1', 'block5_conv1']

# %% [markdown]
# Durante o treinamento, vamos precisar de variáveis com o número de camadas de conteúdo e de estilo, por isso vamos criar essas variáveis agora.

# %%
num_content_layers = len(content_layers)
num_style_layers = len(style_layers)

# %% [markdown]
# Vamos definir uma função que retorna um modelo que, por sua vez, retorna os valores após algumas camadas de interesse.

# %%
def vgg_layers(layer_names):
    # O modelo-base será o VGG 19
    vgg = tf.keras.applications.VGG19(include_top = False, weights = 'imagenet')
    # Este modelo não será treinado...
    vgg.trainable = False
    
    # ... só retornará as saídas em camadas específicas
    outputs = [vgg.get_layer(name).output for name in layer_names]
    
    model = tf.keras.Model([vgg.input], outputs)
    
    return model

# %% [markdown]
# Assim, nós podemos criar um extrator de estilos...

# %%
style_extractor = vgg_layers(style_layers)

# %% [markdown]
# ... e aplicá-lo para retirar o estilo da imagem do Van Gogh.

# %%
style_outputs = style_extractor(style_img * 255)
len(style_outputs)
# Out:
# 5

# %% [markdown]
# Observe que temos uma lista com 5 elementos; cada elemento corresponde à saída de uma das 5 camadas de estilo.

# %%
style_outputs[0].shape
# Out:
# TensorShape([1, 512, 421, 64])

# %% [markdown]
# Inspecionando a saída da primeira dessas camadas, observamos que é uma matriz de 4 dimensões, como esperávamos.
#
# Para o processo de transferência de estilo, nós precisamos calcular uma medida que se chama *Gram matrix*, que é usada para determinar a perda entre a imagem gerada e a imagem de estilo. A Gram matrix é calculada da seguinte forma:

# %%
def gram_matrix(tensor):
    # A função tf.linalg.einsum faz uma operação que se chama de contração do tensor, precisamos usar a forma específica abaixo
    result = tf.linalg.einsum('bijc,bijd->bcd', tensor, tensor)
    input_shape = tf.shape(tensor)
    num_locations = tf.cast(input_shape[1]*input_shape[2], tf.float32)
    return result/num_locations

# %% [markdown]
# Vamos definir uma classe para o modelo que vai processar as imagens e retornar todos os valores de interesse, ou seja, os tensores de conteúdo e as gram matrices dos tensores de estilo.

# %%
class StyleContentModel(tf.keras.models.Model):
    def __init__(self, style_layers, content_layers):
        super().__init__()
        # O modelo-base vai ser construído a partir da função que criamos anteriormente, capaz de produzir os tensores de conteúdo e de estilo
        self.vgg = vgg_layers(style_layers + content_layers)
        self.style_layers = style_layers
        self.content_layers = content_layers
        self.num_style_layers = len(style_layers)
        self.vgg.trainable = False
        
    def call(self, inputs):
        # Precisamos desnormalizar os inputs para o intervalo 0 a 255
        inputs = inputs * 255.
        # A função abaixo faz um preprocessamento padronizado para que imagens possam ser passadas para os modelos da família VGG
        preprocessed_input = tf.keras.applications.vgg19.preprocess_input(inputs)
        outputs = self.vgg(preprocessed_input)
        
        # Como o modelo contido em self.vgg retorna primeiro os tensores de estilo e depois os tensores de conteúdo, seguindo a ordem que definimos na sua construção acima, podemos separá-los com a implementação a seguir
        style_outputs, content_outputs = outputs[:self.num_style_layers], outputs[self.num_style_layers:]
        
        # Gerando as gram matrices para os tensores de estilo
        style_outputs = [gram_matrix(style_output) for style_output in style_outputs]
        
        # Gerando dicionários contendo as saídas
        content_dict = {content_name: value for content_name, value in zip(self.content_layers, content_outputs)}
        style_dict = {style_name: value for style_name, value in zip(self.style_layers, style_outputs)}
        
        return {'content': content_dict, 'style': style_dict}

# %% [markdown]
# Podemos verificar o resultado produzido pelo modelo criando uma instância e passando a imagem de conteúdo por ele.

# %%
extractor = StyleContentModel(style_layers, content_layers)

results = extractor(cont_img)

# %%
for key, value in results.items():
    print(key, ':', value.keys())
# Out:
# content : dict_keys(['block5_conv2'])
# style : dict_keys(['block1_conv1', 'block2_conv1', 'block3_conv1', 'block4_conv1', 'block5_conv1'])

# %% [markdown]
# Como esperado, nós vemos que a variável `results` contém duas chaves, `content` e `style`, e cada uma contém outros dicionários cujas chaves são os nomes das camadas correspondentes. Estes dicionários internos contém os tensores de conteúdo e as gram matrices de estilo.

# %% [markdown]
# Agora vamos definir os valores para os alvos de conteúdo e de estilo, que são as respectivas imagens passadas pelo extrator acima. Durante o treinamento da rede, a imagem gerada vai ser comparada com esses alvos com o objetivo de minimizar as perdas de conteúdo em comparação à imagem de conteúdo, e as perdas de estilo em comparação à imagem de estilo.

# %%
style_targets = extractor(style_img)['style']
content_targets = extractor(cont_img)['content']

# %% [markdown]
# A imagem com conteúdo e estilo fusionado vai ser gerada a partir da imagem de conteúdo original. Ela vai ser atualizada durante o treinamento, por isso, vamos criar um tensor variável baseado na imagem original.

# %%
new_img = tf.Variable(cont_img)

# %% [markdown]
# Definimos então um peso para o conteúdo e para o estilo, que será usado no cálculo de custo total durante o treinamento.

# %%
content_weight = 1e4
style_weight = 1e-2

# %% [markdown]
# Por fim, definimos o otimizador do processo de treinamento.

# %%
opt = tf.optimizers.Adam(learning_rate = 0.002)

# %% [markdown]
# ## 5. Treinamento

# %%
epochs = 3000
print_loss_every = 10
print_images_every = 500

start = datetime.now()

for epoch in range(epochs):
    with tf.GradientTape() as tape:
        # Gerando tensores relacionados ao conteúdo e ao estilo da imagem que está sendo atualizada
        outputs = extractor(new_img)
        
        # Separando as saídas de conteúdo e de estilo
        content_outputs = outputs['content']
        style_outputs = outputs['style']
        
        # Calculando as perdas de conteúdo e de estilo (MSE)
        content_loss = tf.add_n([tf.reduce_mean((content_outputs[name] - content_targets[name])**2) for name in content_outputs.keys()])
        style_loss = tf.add_n([tf.reduce_mean((style_outputs[name] - style_targets[name])**2) for name in style_outputs.keys()])
        
        # Calculando a perda total como uma soma ponderada das perdas de conteúdo e de estilo
        total_loss = content_loss * content_weight / num_content_layers + style_loss * style_weight / num_style_layers
        
    # Determinando os gradientes em relação à nova imagem
    grad = tape.gradient(total_loss, new_img)
    
    # Aplicando os gradientes/atualizando os valores
    opt.apply_gradients([(grad, new_img)])
    
    # Aplicando uma função `clip` para evitar que os valores dos pixels extrapole o intervalo [0, 1] e atualizando a variável `new_img`
    new_img.assign(tf.clip_by_value(new_img, clip_value_min = 0.0, clip_value_max = 1.0))
    
    # Dados de treinamento da época
    if (epoch + 1) % print_loss_every == 0:
        print('ÉPOCA {:04d}/{} | perda conteúdo: {:3.3f} | perda estilo: {:3.3f} | perda total: {}'.format(epoch + 1, 
                                                                                                           epochs, 
                                                                                                           content_loss.numpy(),
                                                                                                           style_loss.numpy(),
                                                                                                           total_loss.numpy()))

    # Mostrando resultados intermediários
    if (epoch + 1) % print_images_every == 0:
        fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
        ax1.imshow(show_img(cont_img))
        ax1.set_title('Imagem de conteúdo')
        ax2.imshow(show_img(style_img))
        ax2.set_title('Imagem de estilo')
        ax3.imshow(show_img(new_img))
        ax3.set_title('Nova imagem')
        plt.show()

end = datetime.now()

print('Processo demorou {}'.format(end - start))
# Out:
# ÉPOCA 0010/3000 | perda conteúdo: 373.697 | perda estilo: 18320392192.000 | perda total: 40377756.0
# ÉPOCA 0020/3000 | perda conteúdo: 420.511 | perda estilo: 10250820608.000 | perda total: 24706748.0
# ÉPOCA 0030/3000 | perda conteúdo: 385.213 | perda estilo: 6730972672.000 | perda total: 17314078.0
# ÉPOCA 0040/3000 | perda conteúdo: 345.826 | perda estilo: 4827032064.000 | perda total: 13112322.0
# ÉPOCA 0050/3000 | perda conteúdo: 315.121 | perda estilo: 3705229312.000 | perda total: 10561666.0
# ÉPOCA 0060/3000 | perda conteúdo: 292.791 | perda estilo: 2991448064.000 | perda total: 8910805.0
# ÉPOCA 0070/3000 | perda conteúdo: 274.937 | perda estilo: 2512636928.000 | perda total: 7774642.0
# ÉPOCA 0080/3000 | perda conteúdo: 260.395 | perda estilo: 2171644928.000 | perda total: 6947237.0
# ÉPOCA 0090/3000 | perda conteúdo: 248.706 | perda estilo: 1916635648.000 | perda total: 6320335.5
# ÉPOCA 0100/3000 | perda conteúdo: 239.071 | perda estilo: 1718469632.000 | perda total: 5827646.0
# ÉPOCA 0110/3000 | perda conteúdo: 230.570 | perda estilo: 1562137984.000 | perda total: 5429978.0
# ÉPOCA 0120/3000 | perda conteúdo: 223.105 | perda estilo: 1435539072.000 | perda total: 5102129.0
# ÉPOCA 0130/3000 | perda conteúdo: 216.194 | perda estilo: 1331942784.000 | perda total: 4825829.0
# ÉPOCA 0140/3000 | perda conteúdo: 209.775 | perda estilo: 1245534848.000 | perda total: 4588824.0
# ÉPOCA 0150/3000 | perda conteúdo: 204.107 | perda estilo: 1170698880.000 | perda total: 4382469.0
# ÉPOCA 0160/3000 | perda conteúdo: 198.762 | perda estilo: 1106805120.000 | perda total: 4201226.0
# ÉPOCA 0170/3000 | perda conteúdo: 193.967 | perda estilo: 1050873216.000 | perda total: 4041421.0
# ÉPOCA 0180/3000 | perda conteúdo: 189.430 | perda estilo: 1002240576.000 | perda total: 3898777.0
# ÉPOCA 0190/3000 | perda conteúdo: 185.434 | perda estilo: 958150720.000 | perda total: 3770645.0
# ÉPOCA 0200/3000 | perda conteúdo: 181.741 | perda estilo: 918665024.000 | perda total: 3654742.5
# ÉPOCA 0210/3000 | perda conteúdo: 178.178 | perda estilo: 883470400.000 | perda total: 3548725.75
# ÉPOCA 0220/3000 | perda conteúdo: 174.779 | perda estilo: 851746496.000 | perda total: 3451286.25
# ÉPOCA 0230/3000 | perda conteúdo: 171.677 | perda estilo: 822376768.000 | perda total: 3361520.5
# ÉPOCA 0240/3000 | perda conteúdo: 168.876 | perda estilo: 795115008.000 | perda total: 3278985.5
# ÉPOCA 0250/3000 | perda conteúdo: 166.216 | perda estilo: 770422336.000 | perda total: 3203003.0
# ÉPOCA 0260/3000 | perda conteúdo: 163.733 | perda estilo: 747720832.000 | perda total: 3132770.75
# ÉPOCA 0270/3000 | perda conteúdo: 161.331 | perda estilo: 726675520.000 | perda total: 3066660.0
# ÉPOCA 0280/3000 | perda conteúdo: 159.113 | perda estilo: 707026432.000 | perda total: 3005184.0
# ÉPOCA 0290/3000 | perda conteúdo: 156.992 | perda estilo: 688949056.000 | perda total: 2947815.0
# ÉPOCA 0300/3000 | perda conteúdo: 154.949 | perda estilo: 672284352.000 | perda total: 2894056.5
# ÉPOCA 0310/3000 | perda conteúdo: 153.084 | perda estilo: 656437824.000 | perda total: 2843717.0
# ÉPOCA 0320/3000 | perda conteúdo: 151.295 | perda estilo: 641636800.000 | perda total: 2796228.0
# ÉPOCA 0330/3000 | perda conteúdo: 149.639 | perda estilo: 627635328.000 | perda total: 2751658.5
# ÉPOCA 0340/3000 | perda conteúdo: 148.067 | perda estilo: 614477312.000 | perda total: 2709627.0
# ÉPOCA 0350/3000 | perda conteúdo: 146.532 | perda estilo: 602382080.000 | perda total: 2670088.5
# ÉPOCA 0360/3000 | perda conteúdo: 145.121 | perda estilo: 590694592.000 | perda total: 2632603.25
# ÉPOCA 0370/3000 | perda conteúdo: 143.710 | perda estilo: 579903936.000 | perda total: 2596906.25
# ÉPOCA 0380/3000 | perda conteúdo: 142.395 | perda estilo: 569555840.000 | perda total: 2563065.5
# ÉPOCA 0390/3000 | perda conteúdo: 141.194 | perda estilo: 559424064.000 | perda total: 2530787.0
# ÉPOCA 0400/3000 | perda conteúdo: 140.024 | perda estilo: 549930624.000 | perda total: 2500106.0
# ÉPOCA 0410/3000 | perda conteúdo: 138.929 | perda estilo: 540827008.000 | perda total: 2470943.75
# ÉPOCA 0420/3000 | perda conteúdo: 137.843 | perda estilo: 532297376.000 | perda total: 2443028.25
# ÉPOCA 0430/3000 | perda conteúdo: 136.727 | perda estilo: 524509280.000 | perda total: 2416290.5
# ÉPOCA 0440/3000 | perda conteúdo: 135.714 | perda estilo: 516745664.000 | perda total: 2390633.75
# ÉPOCA 0450/3000 | perda conteúdo: 134.713 | perda estilo: 509474816.000 | perda total: 2366083.5
# ÉPOCA 0460/3000 | perda conteúdo: 133.754 | perda estilo: 502451808.000 | perda total: 2342445.75
# ÉPOCA 0470/3000 | perda conteúdo: 132.793 | perda estilo: 495981792.000 | perda total: 2319896.0
# ÉPOCA 0480/3000 | perda conteúdo: 131.834 | perda estilo: 489895296.000 | perda total: 2298128.0
# ÉPOCA 0490/3000 | perda conteúdo: 130.991 | perda estilo: 483678784.000 | perda total: 2277266.75
# ÉPOCA 0500/3000 | perda conteúdo: 130.154 | perda estilo: 477838720.000 | perda total: 2257221.0
# ÉPOCA 0510/3000 | perda conteúdo: 129.347 | perda estilo: 472216448.000 | perda total: 2237898.75
# ÉPOCA 0520/3000 | perda conteúdo: 128.542 | perda estilo: 466872800.000 | perda total: 2219168.75
# ÉPOCA 0530/3000 | perda conteúdo: 127.755 | perda estilo: 461754016.000 | perda total: 2201054.0
# ÉPOCA 0540/3000 | perda conteúdo: 127.044 | perda estilo: 456533696.000 | perda total: 2183508.0
# ÉPOCA 0550/3000 | perda conteúdo: 126.380 | perda estilo: 451383040.000 | perda total: 2166565.0
# ÉPOCA 0560/3000 | perda conteúdo: 125.678 | perda estilo: 446705568.000 | perda total: 2150193.0
# ÉPOCA 0570/3000 | perda conteúdo: 125.027 | perda estilo: 441963776.000 | perda total: 2134199.5
# ÉPOCA 0580/3000 | perda conteúdo: 124.345 | perda estilo: 437599872.000 | perda total: 2118651.25
# ÉPOCA 0590/3000 | perda conteúdo: 123.688 | perda estilo: 433369856.000 | perda total: 2103616.75
# ÉPOCA 0600/3000 | perda conteúdo: 123.075 | perda estilo: 429142912.000 | perda total: 2089032.0
# ÉPOCA 0610/3000 | perda conteúdo: 122.479 | perda estilo: 425060832.000 | perda total: 2074914.375
# ÉPOCA 0620/3000 | perda conteúdo: 121.883 | perda estilo: 421202656.000 | perda total: 2061236.75
# ÉPOCA 0630/3000 | perda conteúdo: 121.306 | perda estilo: 417490784.000 | perda total: 2048044.0
# ÉPOCA 0640/3000 | perda conteúdo: 120.748 | perda estilo: 413902048.000 | perda total: 2035283.25
# ÉPOCA 0650/3000 | perda conteúdo: 120.223 | perda estilo: 410370656.000 | perda total: 2022967.25
# ÉPOCA 0660/3000 | perda conteúdo: 119.710 | perda estilo: 406899808.000 | perda total: 2010898.25
# ÉPOCA 0670/3000 | perda conteúdo: 119.171 | perda estilo: 403675584.000 | perda total: 1999064.5
# ÉPOCA 0680/3000 | perda conteúdo: 118.663 | perda estilo: 400476352.000 | perda total: 1987582.5
# ÉPOCA 0690/3000 | perda conteúdo: 118.207 | perda estilo: 397195008.000 | perda total: 1976460.25
# ÉPOCA 0700/3000 | perda conteúdo: 117.699 | perda estilo: 394294816.000 | perda total: 1965579.25
# ÉPOCA 0710/3000 | perda conteúdo: 117.196 | perda estilo: 391564896.000 | perda total: 1955089.625
# ÉPOCA 0720/3000 | perda conteúdo: 116.767 | perda estilo: 388591936.000 | perda total: 1944852.625
# ÉPOCA 0730/3000 | perda conteúdo: 116.304 | perda estilo: 385899104.000 | perda total: 1934843.25
# ÉPOCA 0740/3000 | perda conteúdo: 115.861 | perda estilo: 383224512.000 | perda total: 1925061.875
# ÉPOCA 0750/3000 | perda conteúdo: 115.422 | perda estilo: 380649344.000 | perda total: 1915518.125
# ÉPOCA 0760/3000 | perda conteúdo: 114.993 | perda estilo: 378161888.000 | perda total: 1906250.375
# ÉPOCA 0770/3000 | perda conteúdo: 114.592 | perda estilo: 375672192.000 | perda total: 1897261.5
# ÉPOCA 0780/3000 | perda conteúdo: 114.207 | perda estilo: 373202144.000 | perda total: 1888475.625
# ÉPOCA 0790/3000 | perda conteúdo: 113.775 | perda estilo: 370989216.000 | perda total: 1879729.125
# ÉPOCA 0800/3000 | perda conteúdo: 113.348 | perda estilo: 368857312.000 | perda total: 1871192.875
# ÉPOCA 0810/3000 | perda conteúdo: 112.952 | perda estilo: 366623552.000 | perda total: 1862769.125
# ÉPOCA 0820/3000 | perda conteúdo: 112.521 | perda estilo: 364651968.000 | perda total: 1854513.875
# ÉPOCA 0830/3000 | perda conteúdo: 112.114 | perda estilo: 362628352.000 | perda total: 1846395.75
# ÉPOCA 0840/3000 | perda conteúdo: 111.717 | perda estilo: 360639104.000 | perda total: 1838443.75
# ÉPOCA 0850/3000 | perda conteúdo: 111.349 | perda estilo: 358581600.000 | perda total: 1830655.5
# ÉPOCA 0860/3000 | perda conteúdo: 110.986 | perda estilo: 356566464.000 | perda total: 1822994.125
# ÉPOCA 0870/3000 | perda conteúdo: 110.592 | perda estilo: 354812704.000 | perda total: 1815544.125
# ÉPOCA 0880/3000 | perda conteúdo: 110.253 | perda estilo: 352789792.000 | perda total: 1808105.5
# ÉPOCA 0890/3000 | perda conteúdo: 109.874 | perda estilo: 351066048.000 | perda total: 1800876.0
# ÉPOCA 0900/3000 | perda conteúdo: 109.552 | perda estilo: 349156512.000 | perda total: 1793829.5
# ÉPOCA 0910/3000 | perda conteúdo: 109.238 | perda estilo: 347287520.000 | perda total: 1786957.75
# ÉPOCA 0920/3000 | perda conteúdo: 108.919 | perda estilo: 345531296.000 | perda total: 1780254.0
# ÉPOCA 0930/3000 | perda conteúdo: 108.607 | perda estilo: 343795584.000 | perda total: 1773660.25
# ÉPOCA 0940/3000 | perda conteúdo: 108.265 | perda estilo: 342275872.000 | perda total: 1767198.75
# ÉPOCA 0950/3000 | perda conteúdo: 107.949 | perda estilo: 340639168.000 | perda total: 1760767.5
# ÉPOCA 0960/3000 | perda conteúdo: 107.644 | perda estilo: 339045600.000 | perda total: 1754535.0
# ÉPOCA 0970/3000 | perda conteúdo: 107.348 | perda estilo: 337477696.000 | perda total: 1748432.5
# ÉPOCA 0980/3000 | perda conteúdo: 107.052 | perda estilo: 335920128.000 | perda total: 1742358.0
# ÉPOCA 0990/3000 | perda conteúdo: 106.793 | perda estilo: 334248992.000 | perda total: 1736431.25
# ÉPOCA 1000/3000 | perda conteúdo: 106.537 | perda estilo: 332613728.000 | perda total: 1730600.75
# ÉPOCA 1010/3000 | perda conteúdo: 106.236 | perda estilo: 331276384.000 | perda total: 1724917.0
# ÉPOCA 1020/3000 | perda conteúdo: 106.013 | perda estilo: 329606944.000 | perda total: 1719340.875
# ÉPOCA 1030/3000 | perda conteúdo: 105.732 | perda estilo: 328290240.000 | perda total: 1713900.25
# ÉPOCA 1040/3000 | perda conteúdo: 105.465 | perda estilo: 326971680.000 | perda total: 1708595.0
# ÉPOCA 1050/3000 | perda conteúdo: 105.235 | perda estilo: 325474240.000 | perda total: 1703297.5
# ÉPOCA 1060/3000 | perda conteúdo: 105.001 | perda estilo: 324067936.000 | perda total: 1698142.625
# ÉPOCA 1070/3000 | perda conteúdo: 104.775 | perda estilo: 322664448.000 | perda total: 1693074.875
# ÉPOCA 1080/3000 | perda conteúdo: 104.521 | perda estilo: 321409856.000 | perda total: 1688028.5
# ÉPOCA 1090/3000 | perda conteúdo: 104.299 | perda estilo: 320081184.000 | perda total: 1683156.125
# ÉPOCA 1100/3000 | perda conteúdo: 104.063 | perda estilo: 318848256.000 | perda total: 1678330.5
# ÉPOCA 1110/3000 | perda conteúdo: 103.830 | perda estilo: 317615712.000 | perda total: 1673534.25
# ÉPOCA 1120/3000 | perda conteúdo: 103.580 | perda estilo: 316490976.000 | perda total: 1668786.625
# ÉPOCA 1130/3000 | perda conteúdo: 103.360 | perda estilo: 315308480.000 | perda total: 1664213.125
# ÉPOCA 1140/3000 | perda conteúdo: 103.161 | perda estilo: 314042720.000 | perda total: 1659697.25
# ÉPOCA 1150/3000 | perda conteúdo: 102.927 | perda estilo: 313004160.000 | perda total: 1655278.25
# ÉPOCA 1160/3000 | perda conteúdo: 102.720 | perda estilo: 311845280.000 | perda total: 1650889.75
# ÉPOCA 1170/3000 | perda conteúdo: 102.510 | perda estilo: 310714624.000 | perda total: 1646526.25
# ÉPOCA 1180/3000 | perda conteúdo: 102.303 | perda estilo: 309632896.000 | perda total: 1642297.75
# ÉPOCA 1190/3000 | perda conteúdo: 102.084 | perda estilo: 308585632.000 | perda total: 1638010.625
# ÉPOCA 1200/3000 | perda conteúdo: 101.859 | perda estilo: 307632032.000 | perda total: 1633850.0
# ÉPOCA 1210/3000 | perda conteúdo: 101.643 | perda estilo: 306634208.000 | perda total: 1629695.125
# ÉPOCA 1220/3000 | perda conteúdo: 101.464 | perda estilo: 305486560.000 | perda total: 1625614.5
# ÉPOCA 1230/3000 | perda conteúdo: 101.278 | perda estilo: 304484640.000 | perda total: 1621746.75
# ÉPOCA 1240/3000 | perda conteúdo: 101.088 | perda estilo: 303453600.000 | perda total: 1617791.5
# ÉPOCA 1250/3000 | perda conteúdo: 100.899 | perda estilo: 302459776.000 | perda total: 1613909.75
# ÉPOCA 1260/3000 | perda conteúdo: 100.686 | perda estilo: 301641248.000 | perda total: 1610146.0
# ÉPOCA 1270/3000 | perda conteúdo: 100.502 | perda estilo: 300729376.000 | perda total: 1606478.5
# ÉPOCA 1280/3000 | perda conteúdo: 100.359 | perda estilo: 299663040.000 | perda total: 1602916.375
# ÉPOCA 1290/3000 | perda conteúdo: 100.147 | perda estilo: 298861024.000 | perda total: 1599189.375
# ÉPOCA 1300/3000 | perda conteúdo: 99.943 | perda estilo: 298086560.000 | perda total: 1595607.25
# ÉPOCA 1310/3000 | perda conteúdo: 99.796 | perda estilo: 297065760.000 | perda total: 1592090.75
# ÉPOCA 1320/3000 | perda conteúdo: 99.616 | perda estilo: 296221408.000 | perda total: 1588603.875
# ÉPOCA 1330/3000 | perda conteúdo: 99.409 | perda estilo: 295554688.000 | perda total: 1585195.75
# ÉPOCA 1340/3000 | perda conteúdo: 99.240 | perda estilo: 294676352.000 | perda total: 1581750.625
# ÉPOCA 1350/3000 | perda conteúdo: 99.048 | perda estilo: 293932480.000 | perda total: 1578341.0
# ÉPOCA 1360/3000 | perda conteúdo: 98.883 | perda estilo: 293106944.000 | perda total: 1575043.0
# ÉPOCA 1370/3000 | perda conteúdo: 98.734 | perda estilo: 292206432.000 | perda total: 1571750.0
# ÉPOCA 1380/3000 | perda conteúdo: 98.593 | perda estilo: 291256640.000 | perda total: 1568439.25
# ÉPOCA 1390/3000 | perda conteúdo: 98.397 | perda estilo: 290650240.000 | perda total: 1565271.0
# ÉPOCA 1400/3000 | perda conteúdo: 98.246 | perda estilo: 289766912.000 | perda total: 1561991.5
# ÉPOCA 1410/3000 | perda conteúdo: 98.051 | perda estilo: 289146336.000 | perda total: 1558800.0
# ÉPOCA 1420/3000 | perda conteúdo: 97.894 | perda estilo: 288384480.000 | perda total: 1555704.25
# ÉPOCA 1430/3000 | perda conteúdo: 97.764 | perda estilo: 287497600.000 | perda total: 1552633.25
# ÉPOCA 1440/3000 | perda conteúdo: 97.596 | perda estilo: 286832832.000 | perda total: 1549622.125
# ÉPOCA 1450/3000 | perda conteúdo: 97.422 | perda estilo: 286196352.000 | perda total: 1546617.375
# ÉPOCA 1460/3000 | perda conteúdo: 97.263 | perda estilo: 285508928.000 | perda total: 1543643.0
# ÉPOCA 1470/3000 | perda conteúdo: 97.114 | perda estilo: 284769280.000 | perda total: 1540680.75
# ÉPOCA 1480/3000 | perda conteúdo: 96.959 | perda estilo: 284063520.000 | perda total: 1537716.75
# ÉPOCA 1490/3000 | perda conteúdo: 96.800 | perda estilo: 283477376.000 | perda total: 1534953.25
# ÉPOCA 1500/3000 | perda conteúdo: 96.636 | perda estilo: 282813856.000 | perda total: 1531983.75
# ÉPOCA 1510/3000 | perda conteúdo: 96.490 | perda estilo: 282123072.000 | perda total: 1529151.0
# ÉPOCA 1520/3000 | perda conteúdo: 96.331 | perda estilo: 281510208.000 | perda total: 1526335.0
# ÉPOCA 1530/3000 | perda conteúdo: 96.187 | perda estilo: 280814688.000 | perda total: 1523496.75
# ÉPOCA 1540/3000 | perda conteúdo: 96.048 | perda estilo: 280131968.000 | perda total: 1520742.875
# ÉPOCA 1550/3000 | perda conteúdo: 95.893 | perda estilo: 279511936.000 | perda total: 1517952.25
# ÉPOCA 1560/3000 | perda conteúdo: 95.727 | perda estilo: 278951584.000 | perda total: 1515173.625
# ÉPOCA 1570/3000 | perda conteúdo: 95.576 | perda estilo: 278341792.000 | perda total: 1512441.5
# ÉPOCA 1580/3000 | perda conteúdo: 95.444 | perda estilo: 277704224.000 | perda total: 1509852.625
# ÉPOCA 1590/3000 | perda conteúdo: 95.313 | perda estilo: 277024896.000 | perda total: 1507175.0
# ÉPOCA 1600/3000 | perda conteúdo: 95.174 | perda estilo: 276419520.000 | perda total: 1504579.25
# ÉPOCA 1610/3000 | perda conteúdo: 95.032 | perda estilo: 275841984.000 | perda total: 1502007.625
# ÉPOCA 1620/3000 | perda conteúdo: 94.886 | perda estilo: 275297696.000 | perda total: 1499452.75
# ÉPOCA 1630/3000 | perda conteúdo: 94.720 | perda estilo: 274890816.000 | perda total: 1496976.75
# ÉPOCA 1640/3000 | perda conteúdo: 94.593 | perda estilo: 274270784.000 | perda total: 1494474.625
# ÉPOCA 1650/3000 | perda conteúdo: 94.453 | perda estilo: 273682464.000 | perda total: 1491897.5
# ÉPOCA 1660/3000 | perda conteúdo: 94.332 | perda estilo: 273103296.000 | perda total: 1489530.0
# ÉPOCA 1670/3000 | perda conteúdo: 94.198 | perda estilo: 272579744.000 | perda total: 1487139.0
# ÉPOCA 1680/3000 | perda conteúdo: 94.113 | perda estilo: 271851328.000 | perda total: 1484836.5
# ÉPOCA 1690/3000 | perda conteúdo: 93.998 | perda estilo: 271249344.000 | perda total: 1482475.25
# ÉPOCA 1700/3000 | perda conteúdo: 93.863 | perda estilo: 270738368.000 | perda total: 1480105.5
# ÉPOCA 1710/3000 | perda conteúdo: 93.743 | perda estilo: 270269312.000 | perda total: 1477966.25
# ÉPOCA 1720/3000 | perda conteúdo: 93.647 | perda estilo: 269600096.000 | perda total: 1475671.5
# ÉPOCA 1730/3000 | perda conteúdo: 93.545 | perda estilo: 269062752.000 | perda total: 1473579.0
# ÉPOCA 1740/3000 | perda conteúdo: 93.410 | perda estilo: 268597952.000 | perda total: 1471291.25
# ÉPOCA 1750/3000 | perda conteúdo: 93.278 | perda estilo: 268116912.000 | perda total: 1469016.0
# ÉPOCA 1760/3000 | perda conteúdo: 93.155 | perda estilo: 267666848.000 | perda total: 1466887.75
# ÉPOCA 1770/3000 | perda conteúdo: 93.030 | perda estilo: 267200416.000 | perda total: 1464699.75
# ÉPOCA 1780/3000 | perda conteúdo: 92.945 | perda estilo: 266574736.000 | perda total: 1462602.75
# ÉPOCA 1790/3000 | perda conteúdo: 92.843 | perda estilo: 266060784.000 | perda total: 1460553.875
# ÉPOCA 1800/3000 | perda conteúdo: 92.722 | perda estilo: 265639248.000 | perda total: 1458498.875
# ÉPOCA 1810/3000 | perda conteúdo: 92.612 | perda estilo: 265199536.000 | perda total: 1456520.25
